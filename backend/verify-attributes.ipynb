# %%
import subprocess, os, sys, textwrap
script = r'c:\denfit-ecommerce 3\backend\verify-attributes.cjs'
node = r'C:\Program Files\nodejs\node.exe'
result = subprocess.run([node, script], capture_output=True, text=True)
print(result.stdout)
print(result.stderr)
print('returncode=', result.returncode)
# Out:
# typeof=object
# value={"material":["Leather"],"color":["Black"]}
#
#
# returncode= 0
